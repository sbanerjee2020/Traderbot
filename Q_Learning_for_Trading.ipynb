# %% [markdown]
# <a href="https://colab.research.google.com/github/sbanerjee2020/Traderbot/blob/master/Q_Learning_for_Trading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/llSourcell/Q-Learning-for-Trading
# Out:
# Cloning into 'Q-Learning-for-Trading'...
# remote: Enumerating objects: 25, done.
# remote: Total 25 (delta 0), reused 0 (delta 0), pack-reused 25
# Unpacking objects: 100% (25/25), done.

# %%
#!git config --global user.email "sbanerjee2005@gmail.com"
#!git config --global user.name "***"

# %%
# !ls -al
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Mar 30 14:06 .
# drwxr-xr-x 1 root root 4096 Mar 30 13:49 ..
# drwxr-xr-x 1 root root 4096 Mar 27 20:25 .config
# drwxr-xr-x 4 root root 4096 Mar 30 14:06 Q-Learning-for-Trading
# drwxr-xr-x 7 root root 4096 Mar 30 14:03 Reinforcement_Learning_for_Stock_Prediction
# drwxr-xr-x 1 root root 4096 Mar 27 20:26 sample_data

# %%
os.chdir("Q-Learning-for-Trading")

# %%
# !ls -al
# Out:
# total 44
# drwxr-xr-x 4 root root 4096 Mar 30 14:06 .
# drwxr-xr-x 1 root root 4096 Mar 30 14:06 ..
# -rw-r--r-- 1 root root 1914 Mar 30 14:06 agent.py
# drwxr-xr-x 2 root root 4096 Mar 30 14:06 data
# -rw-r--r-- 1 root root 3562 Mar 30 14:06 envs.py
# drwxr-xr-x 8 root root 4096 Mar 30 14:06 .git
# -rw-r--r-- 1 root root  579 Mar 30 14:06 model.py
# -rw-r--r-- 1 root root 1469 Mar 30 14:06 README.md
# -rw-r--r-- 1 root root   53 Mar 30 14:06 requirements.txt
# -rw-r--r-- 1 root root 2587 Mar 30 14:06 run.py
# -rw-r--r-- 1 root root 1127 Mar 30 14:06 utils.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#     100% |████████████████████████████████| 163kB 6.6MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/2f/ae/a0/126678adc5f1f8905309a4712ea29537999787f610edbcb0a4
# Successfully built gym
# dopamine-rl 1.0.5 has requirement gym>=0.10.5, but you'll have gym 0.9.4 which is incompatible.
# ...
#   Found existing installation: gym 0.10.11
#     Uninstalling gym-0.10.11:
#       Successfully uninstalled gym-0.10.11
# ...

# %%
# !python run.py --mode train
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 32)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 27)                891
# ...
# Total params: 2,203
# Trainable params: 2,203
# Non-trainable params: 0
# _________________________________________________________________
# None
# ...

# %%
# !pwd
# Out:
# /content/Q-Learning-for-Trading

# %%
# !ls -al weights
# Out:
# ls: cannot access 'weights': No such file or directory

# %%
# !python run.py --mode test --weights  weights/201903241358-dqn.h5
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 32)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 27)                891
# ...
# Total params: 2,203
# Trainable params: 2,203
# Non-trainable params: 0
# _________________________________________________________________
# None
# ...
